# %%
import folium
from geopy.distance import geodesic

# Coordinates for 15 S Shafer St, Athens, Ohio
user_latitude, user_longitude = 39.3242, -82.1013

# Create a map centered around the given location
m = folium.Map(location=[user_latitude, user_longitude], zoom_start=15)

# Add a marker for the user's location
folium.Marker(
    [user_latitude, user_longitude],
    popup="Your Location",
    tooltip="Your Location",
    icon=folium.Icon(color='blue', icon='home')
).add_to(m)

# List of bus stops with coordinates and schedules
bus_stops = [
    {"name": "West Mulberry St Baker Center Bus Hub", "location": [39.325579562917234, -82.10174019597717], "times": "7:32a, 8:32, 9:32, 10:32, 11:32, 12:32p"},
    {"name": "Court / President Chubb, Lindley, Bentley", "location": [39.32648385107074, -82.10136237708191], "times": "7:33, 8:33, 9:33, 10:33, 11:33, 12:33"},
    {"name": "Court / Washington Courthouse, Peoples Bank", "location": [39.32934803836249, -82.10110478447564], "times": "7:35, 8:35, 9:35, 10:35, 11:35, 12:35"},
    {"name": "Court / W State Casa, Blue Eagle", "location": [39.33138096521596, -82.10090208804377], "times": "7:36, 8:36, 9:36, 10:36, 11:36, 12:36"},
    {"name": "Carpenter / Court Masonic Lodge, Broney's", "location": [39.332349876676794, -82.10158687345103], "times": "7:37, 8:37, 9:37, 10:37, 11:37, 12:37"},
    {"name": "Carpenter / Mound St Johnny Appleseed Park", "location": [39.33258379213305, -82.10378762594716], "times": "7:37, 8:37, 9:37, 10:37, 11:37, 12:37"},
    {"name": "Lancaster / 2nd St Mechanic On Duty, Fire Station", "location": [39.33609805280768, -82.10448385180295], "times": "7:38, 8:38, 9:38, 10:38, 11:38, 12:38"},
    {"name": "Columbus Rd / Sunset Dr Dairy Queen, Ohio Valley Museum", "location": [39.33940791687895, -82.10376610044143], "times": "7:39, 8:39, 9:39, 10:39, 11:39, 12:39"},
    {"name": "91 Columbus Rd Devil's Kettle, ACEnet, Curtis Tow", "location": [39.34825964338444, -82.09520652244501], "times": "7:40, 8:40, 9:40, 10:40, 11:40, 12:40"},
    {"name": "165 Columbus Rd Sport Cycles, Mum Mum Hibachi", "location": [39.35263023216852, -82.09847208682298], "times": "7:41, 8:41, 9:41, 10:41, 11:41, 12:41"},
    {"name": "Columbus Rd / Dorr Rd Alvis, Vision Source", "location": [39.35431508697344, -82.10018267359852], "times": "7:41, 8:42, 9:42, 10:42, 11:42, 12:42"},
    {"name": "223 Columbus Rd Athens Dental Arts, HRS, Valero", "location": [39.357467937835274, -82.10352614131938], "times": "7:42, 8:42, 9:42, 10:42, 11:42, 12:42"},
    {"name": "S.R. 682 / Poston Rd Gigi's, HVB", "location": [39.368174149196534, -82.131751513195], "times": "7:46, 8:46, 9:46, 10:46, 11:46, 12:46"},
    {"name": "Arrive Plains Plaza Mall Piggly Wiggly, C&E", "location": [39.374168082143406, -82.13492637507211], "times": "7:48a, 8:48, 9:48, 10:48, 11:48, 12:48p"},
    {"name": "Leave Plains Plaza Mall Work Station, Subway", "location": [39.374168082143406, -82.13492637507211], "times": "7:56a, 8:56, 9:56, 10:56, 11:56, 12:56p"},
    {"name": "Connett Rd / Bean Rd Plains Elementary School", "location": [39.37049636767326, -82.14192918354195], "times": "8:00, 9:00, 10:00, 11:00, 12:00p, 1:00"},
    {"name": "S.R. 682 / E 1st St Plains Library, Little Italy Pizza", "location": [39.368110927348226, -82.1320199855305], "times": "8:02, 9:02, 10:02, 11:02, 12:02, 1:02"},
    {"name": "45 E 4th St Hickory Creek, Evergreen Estates", "location": [39.361269655111975, -82.12357412319349], "times": "8:04, 9:04, 10:04, 11:04, 12:04, 1:04"},
    {"name": "Kershaw Greene The Falls, Unv. Estates, Little Fish, AEP", "location": [39.33536725267712, -82.13025528356697], "times": "8:10, 9:10, 10:10, 11:10, 12:10, 1:10"},
    {"name": "West Union / Bikeway VA Clinic, Catalyst Cafe", "location": [39.33121258577749, -82.12304346337207], "times": "8:13, 9:13, 10:13, 11:13, 12:13, 1:13"},
    {"name": "West Union / Herrold ReStore, State Farm, Larry's", "location": [39.33093864297884, -82.1201456885848], "times": "8:13, 9:13, 10:13, 11:13, 12:13, 1:13"},
    {"name": "O'Bleness Hospital Castrop Center, Cornwell Ctr", "location": [39.32815636784879, -82.11445481638816], "times": "8:16, 9:16, 10:16, 11:16, 12:16, 1:16"},
    {"name": "305 West Union Fairgrounds, Health Dpt, Seamans", "location": [39.32995754658749, -82.11458654571608], "times": "8:18, 9:18, 10:18, 11:18, 12:18, 1:18"},
    {"name": "Innovation Center, Athens Gardens", "location": [39.33452901994828, -82.11479202088482], "times": "8:02, 9:02, 10:02, 11:02, 12:02, 1:02"},
    {"name": "West State / Central, Millers Chicken", "location": [39.333363913073626, -82.11171354572456], "times": "8:04, 9:04, 10:04, 11:04, 12:04, 1:04"},
    {"name": "Shafer / West Union, Union Cemetery", "location": [39.32977935882223, -82.1102576077521], "times": "8:10, 9:10, 10:10, 11:10, 12:10, 1:10"},
    {"name": "West Union / Factory St, WUSOC, OUHR ", "location": [39.329848777509625, -82.10783830761581], "times": "8:13, 9:13, 10:13, 11:13, 12:13, 1:13"},
    {"name": "93 West Union St, Beasley Mill", "location": [39.32882746943734, -82.1046899553994], "times": "8:13, 9:13, 10:13, 11:13, 12:13, 1:13"},
    {"name": "Richland / President St, RTech, Bentley", "location": [39.32679870875329, -82.10291120158219], "times": "8:16, 9:16, 10:16, 11:16, 12:16, 1:16"},
    {"name": "West Mulberry St Baker Center Bus Hub", "location": [39.325579562917234, -82.10174019597717], "times": "8:18, 9:18, 10:18, 11:18, 12:18, 1:18"},
    
]

# Find the nearest bus stop
nearest_stop = None
min_distance = float('inf')

for stop in bus_stops:
    stop_latitude, stop_longitude = stop["location"]
    distance = geodesic((user_latitude, user_longitude), (stop_latitude, stop_longitude)).miles
    if distance < min_distance:
        min_distance = distance
        nearest_stop = stop

# Add markers for each bus stop and highlight the nearest one with a standard icon
for stop in bus_stops:
    stop_latitude, stop_longitude = stop["location"]
    popup_text = f"{stop['name']}<br>Bus Times: {stop['times']}"
    if stop == nearest_stop:
        folium.Marker(
            [stop_latitude, stop_longitude],
            popup=popup_text,
            tooltip=stop["name"],
            icon=folium.Icon(color='red')
        ).add_to(m)
    else:
        folium.Marker(
            [stop_latitude, stop_longitude],
            popup=popup_text,
            tooltip=stop["name"]
        ).add_to(m)

# Save the map to an HTML file
m.save('ohio_university_bus_stations.html')

# %%
import geopandas as gpd

# Correct URL to the raw CSV file
url = "https://raw.githubusercontent.com/OA143614/bustimetable/main/buscommon.csv"

# Read the CSV file
boros = gpd.read_file(url)

# Display the data
print(boros)
import folium
from geopy.distance import geodesic

# Coordinates for 15 S Shafer St, Athens, Ohio
user_latitude, user_longitude = 39.3242, -82.1013

# Create a map centered around the given location
m = folium.Map(location=[user_latitude, user_longitude], zoom_start=15)

# Add a marker for the user's location
folium.Marker(
    [user_latitude, user_longitude],
    popup="Your Location",
    tooltip="Your Location",
    icon=folium.Icon(color='blue', icon='home')
).add_to(m)

# Find the nearest bus stop
nearest_stop = None
min_distance = float('inf')

for stop in boros:
    stop_latitude, stop_longitude = stop["location"]
    distance = geodesic((user_latitude, user_longitude), (stop_latitude, stop_longitude)).miles
    if distance < min_distance:
        min_distance = distance
        nearest_stop = stop

# Add markers for each bus stop and highlight the nearest one with a standard icon
for stop in boros:
    stop_latitude, stop_longitude = stop["location"]
    popup_text = f"{stop['name']}<br>Bus Times: {stop['times']}"
    if stop == nearest_stop:
        folium.Marker(
            [stop_latitude, stop_longitude],
            popup=popup_text,
            tooltip=stop["name"],
            icon=folium.Icon(color='red')
        ).add_to(m)
    else:
        folium.Marker(
            [stop_latitude, stop_longitude],
            popup=popup_text,
            tooltip=stop["name"]
        ).add_to(m)

# Save the map to an HTML file
m.save('ohio_university_bus_stations.html')
# Out:
#     station   time                               location       day geometry
# 0    common   7.10  39.332363777163295, -82.1107700317955    Monday     None
# 1     Baker   7.20  39.32553391636762, -82.10134322924043    Monday     None
# 2    common   8.15  39.332363777163295, -82.1107700317955    Monday     None
# 3     Baker   8.35  39.32553391636762, -82.10134322924043    Monday     None
# 4    common   9.20  39.332363777163295, -82.1107700317955    Monday     None
# ..      ...    ...                                    ...       ...      ...
# 107   Baker  18.05  39.32553391636762, -82.10134322924043  Thursday     None
# 108  common  19.15  39.332363777163295, -82.1107700317955  Thursday     None
# 109   Baker  19.35  39.32553391636762, -82.10134322924043  Thursday     None
# 110  common  20.45  39.332363777163295, -82.1107700317955  Thursday     None
# 111   Baker  21.05  39.32553391636762, -82.10134322924043  Thursday     None
#
# [112 rows x 5 columns]
# ...

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium
from geopy.distance import geodesic
from datetime import datetime

# Correct URL to the raw CSV file
url = "https://raw.githubusercontent.com/OA143614/bustimetable/a20f604a97a37cd28155dad340900eb0205bcf05/buscommon.csv"

# Read the CSV file using pandas
df = pd.read_csv(url)


# Function to convert the geometry string to a Point object
def convert_to_point(geom_str):
    geom_str = geom_str.replace("POINT(", "").replace(")", "")
    lon, lat = map(float, geom_str.split(','))
    return Point(lon, lat)

# Apply the function to the 'geometry' column
df['geometry'] = df['geometry'].apply(convert_to_point)

# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='geometry')

#print(df['time'])
#print(df['day'])

# Get the current date and time
current_datetime = datetime.now()

# Get the current day of the week and time
current_day_of_week = current_datetime.strftime("%A")
current_time = current_datetime.strftime("%H:%M:%S")

# Print the current day of the week and time
print("Current day of the week:", current_day_of_week)
print("Current time:", current_time)

# Convert current time to float for comparison
current_time_float = current_datetime.hour + current_datetime.minute / 60

# Match day of the week and time greater than or equal to the timetable
matching_stop = df[(df['day'] == current_day_of_week) & (df['time'] >= current_time_float)].head(1)
print("Matching stop:\n", matching_stop)

# Coordinates for 15 S Shafer St, Athens, Ohio
user_latitude, user_longitude = 39.332409419254944, -82.11133866004694

# Create a map centered around the given location
m = folium.Map(location=[user_latitude, user_longitude], zoom_start=15)

# Add a marker for the user's location
folium.Marker(
    [user_latitude, user_longitude],
    popup="Your Location",
    tooltip="Your Location",
    icon=folium.Icon(color='green', icon='star')
).add_to(m)


# Find the nearest bus stop
nearest_stop = None
min_distance = float('inf')


# Add markers for each bus stop and highlight the nearest one with a standard icon
for _,stop in gdf.iterrows():
    stop_latitude, stop_longitude = stop.geometry.x, stop.geometry.y
    popup_text = f"{stop['station']}<br>Bus Times: {stop['time']} on {stop['day']}"
    
    folium.Marker(
        [stop_latitude, stop_longitude],
        popup=popup_text,
        tooltip=stop["station"]
    ).add_to(m)

# Save the map to an HTML file
m.save('ohio_university_bus_stations.html')

print("Map has been saved to 'ohio_university_bus_stations.html'.")
# Out:
# Current day of the week: Wednesday
# Current time: 14:48:54
# Matching stop:
#     station   time        day                                      geometry
# 81   Baker  15.05  Wednesday  POINT (39.32553391636762 -82.10134322924043)
# Map has been saved to 'ohio_university_bus_stations.html'.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium
from geopy.distance import geodesic
from datetime import datetime

# Correct URL to the raw CSV file
url = "https://raw.githubusercontent.com/OA143614/bustimetable/a20f604a97a37cd28155dad340900eb0205bcf05/buscommon.csv"

# Read the CSV file using pandas
df = pd.read_csv(url)


# Function to convert the geometry string to a Point object
def convert_to_point(geom_str):
    geom_str = geom_str.replace("POINT(", "").replace(")", "")
    lon, lat = map(float, geom_str.split(','))
    return Point(lon, lat)

# Apply the function to the 'geometry' column
df['geometry'] = df['geometry'].apply(convert_to_point)

# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='geometry')

#print(df['time'])
#print(df['day'])

# Get the current date and time
current_datetime = datetime.now()

# Get the current day of the week and time
current_day_of_week = current_datetime.strftime("%A")
current_time = current_datetime.strftime("%H:%M:%S")

# Print the current day of the week and time
print("Current day of the week:", current_day_of_week)
print("Current time:", current_time)

# Convert current time to float for comparison
current_time_float = current_datetime.hour + current_datetime.minute / 60

# Match day of the week and time greater than or equal to the timetable for each station
matching_stops = df[(df['day'] == current_day_of_week) & (df['time'] >= current_time_float)]


# Coordinates for 15 S Shafer St, Athens, Ohio
user_latitude, user_longitude = 39.332409419254944, -82.11133866004694

# Create a map centered around the given location
m = folium.Map(location=[user_latitude, user_longitude], zoom_start=15)

# Add a marker for the user's location
folium.Marker(
    [user_latitude, user_longitude],
    popup="Your Location",
    tooltip="Your Location",
    icon=folium.Icon(color='red', icon='star')
).add_to(m)


# Find the nearest bus stop
nearest_stop = None
min_distance = float('inf')
print(matching_stop.iloc,"here")
# Add markers for each bus stop and highlight the matching one with a standard icon


    
# Add markers for each bus stop and highlight the matching one with a standard icon
for station in df['station'].unique():
    station_stops = matching_stops[matching_stops['station'] == station]
    if not station_stops.empty:
        stop_latitude, stop_longitude = station_stops.iloc[0]['geometry'].x, station_stops.iloc[0]['geometry'].y
        popup_text = f"{station}<br>Bus Times: {station_stops.head(1)['time'].values[0]} on {station_stops.head(1)['day'].values[0]}"
        folium.Marker(
            [stop_latitude, stop_longitude],
            popup=popup_text,
            tooltip=station,
            icon=folium.Icon(color='purple')
        ).add_to(m)
        
# Save the map to an HTML file
m.save('ohio_university_bus_stations.html')
# Out:
# Current day of the week: Wednesday
# Current time: 17:45:34
# Matching stops for common:
#  18.0
# Matching stops for Baker:
#  18.2
# <pandas.core.indexing._iLocIndexer object at 0x000001A2F3767ED0> here
